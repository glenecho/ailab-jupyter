# %%
#https://github.com/Crossme0809/langchain-tutorials/blob/main/Using_OpenAI__LangChain_And_HDBSCAN_Clustering_Documents.ipynb
import os

import hdbscan
import pandas as pd

from langchain import LLMChain
from langchain.chat_models import ChatOpenAI
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.prompts.chat import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate,)
from newsapi.newsapi_client import NewsApiClient

from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
newsapi = NewsApiClient(api_key=os.getenv("NEWSAPI_API_KEY"))

sources_1 = [
    "the-washington-post",
    "the-wall-street-journal",
    "business-insider",
]
sources_2 = [
    "associated-press",
    "bloomberg",
]

recent_articles = []

for source in [sources_1, sources_2]:
    recent_articles.extend(newsapi.get_everything(
        sources=",".join(source),
        language="zh",
        page_size=100
    )["articles"])

# %%
recent_articles
# Out:
# [{'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Kwan Wei Kevin Tan',
#   'title': "Mark Cuban says Elon Musk is a 'genius' for buying X but is also his 'own worst enemy'",
#   'description': '"He really has got a unique chance to do some really incredible things with it if he can get out of his own way," Cuban told GQ.',
#   'url': 'https://www.businessinsider.com/mark-cuban-says-elon-musk-is-his-own-worst-enemy-2023-9',
#   'urlToImage': 'https://i.insider.com/65166ee9c50dce0019136a47?width=1200&format=jpeg',
#   'publishedAt': '2023-09-29T07:04:29Z',
#   'content': 'Mark Cuban (left) and Elon Musk (right).Christopher Willard/ABC via Getty Images; Alain Jocard/AFP via Getty Images\r\n<ul><li>Mark Cuban thinks Elon Musk is his\xa0"own worst enemy" when it comes to mana… [+2541 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'kteo@insider.com (Kai Xiang Teo)',
#   'title': "Meet the average CEO of the top UK companies: He's white, rich, and probably named Andrew",
#   'description': "That's according to an analysis of the CEOs of the top 100 companies on the LSE by human resources publication People Managing People.",
#   'url': 'https://www.businessinsider.com/average-ceo-top-uk-company-ftse-ai-generated-2023-9',
#   'urlToImage': 'https://i.insider.com/651637a598683c001946ae88?width=1200&format=jpeg',
#   'publishedAt': '2023-09-29T04:50:40Z',
#   'content': 'The average CEO of a top UK company is probably named Andrew, according to an analysis of the CEOs of the FTSE100 companies published by human resources publication People Managing People on Tuesday.… [+2049 chars]'},
#  {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#   'author': 'Dan Rosenzweig-ziff',
#   'title': 'How government shutdowns cost taxpayers and the American economy money',
#   'description': 'The administrative cost of furloughs and shuttering offices, as well as late fees on interest payments, further harms American coffers.',
#   'url': 'https://www.washingtonpost.com/business/2023/09/28/government-shutdown-financial-costs-money/',
#   'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/W4B3K2N3QAMDZQNMORJGM6ZW7A_size-normalized.jpg&w=1440',
#   'publishedAt': '2023-09-29T04:36:50Z',
#   'content': 'Return to menuFurloughed federal employees cannot work during a shutdown, but once a deal is reached, they must be paid back for the time they would have been working. That means the government, and … [+947 chars]'},
#  {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#   'author': 'Carolyn Hax',
#   'title': 'Carolyn Hax: What do you say to a parent who mocks your kid’s name on Facebook?',
#   'description': 'One parent mocked a kid’s name on Facebook, another liked it, and the one who chose the name wonders what to say to them both.',
#   'url': 'https://www.washingtonpost.com/advice/2023/09/29/carolyn-hax-mocks-kid-name-facebook/',
#   'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/LEGLW2SX4EI65P3EZWEP46W4OE.jpg&w=1440',
#   'publishedAt': '2023-09-29T04:00:00Z',
#   'content': 'Comment on this story\r\nComment\r\nDear Carolyn: At a back-to-school event, a teacher stumbled over my childs name. My child gave the correct pronunciation, and that was that.\r\nOr I thought it was, unti… [+2979 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'ktan@insider.com (Kwan Wei Kevin Tan)',
#   'title': 'A cowboy-hat-donning, aviator-shades-wearing Elon Musk hiked down south to Texas to try to make a point about migration',
#   'description': 'Musk\'s also claimed on X on Wednesday that the US needs a border wall to keep migrants who don\'t have "some shred of evidence to claim asylum" out.',
#   'url': 'https://www.businessinsider.com/elon-musk-cowboy-hat-southern-border-livestream-2023-9',
#   'urlToImage': 'https://i.insider.com/6516345dc50dce00191367c1?width=1200&format=jpeg',
#   'publishedAt': '2023-09-29T03:57:10Z',
#   'content': 'Elon Musk on Thursday put on a cowboy hat and headed to Texas in what appeared to be an attempt to make a point about migration across the Southern border.\r\n"Elon here. I\'m at Eagle Pass. Just arrive… [+3070 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Huileng Tan',
#   'title': "There's one 'lucky' group of homeowners in America's housing market, says a Zillow economist",
#   'description': "It's those who are downsizing, as prices have gained nearly 50% since the pre-pandemic days, Zillow's Skylar Olsen told MarketWatch.",
#   'url': 'https://www.businessinsider.com/us-real-estate-property-homeowners-downsize-lucky-prices-zillow-economist-2023-9',
#   'urlToImage': 'https://i.insider.com/651629dfc50dce001913674a?width=1200&format=jpeg',
#   'publishedAt': '2023-09-29T03:29:13Z',
#   'content': 'High prices and mortgage rates have hit US home sales.Saul Loeb/AFP/Getty Images\r\n<ul>\n<li>US homeowners who are downsizing now are "lucky," Skylar Olsen, Zillow\'s chief economist told MarketWatch.</… [+2557 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Quentyn Kennemer',
#   'title': 'How to watch Ryder Cup live stream without cable online from anywhere',
#   'description': "Park your golf caddy here for Ryder Cup live streams. Here's how to watch USA and Europe compete for another two years of bragging rights.",
#   'url': 'https://www.businessinsider.com/guides/streaming/how-to-watch-ryder-cup-live-streams-2023',
#   'urlToImage': 'https://i.insider.com/65131cc91c099d0019ad0f53?width=1200&format=jpeg',
#   'publishedAt': '2023-09-29T02:30:01Z',
#   'content': 'Ryder Cup: Where to watch USA and Europe compete for golfing glory.Reuters\r\nWhen you buy through our links, Insider may earn an affiliate commission. Learn moreThe Solheim Cup just wrapped up, and Eu… [+4547 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Erin Snodgrass,Laura Italiano,Lloyd Lee',
#   'title': 'Why Melania Trump may want to revisit her prenup with Donald Trump',
#   'description': "Melania Trump may want to revisit her prenuptial agreement with Donald Trump amid the former president's looming legal troubles, two attorneys said.",
#   'url': 'https://www.businessinsider.com/melania-trump-prenuptial-agreement-prenup-donald-trump-barron-2024-election-2023-9',
#   'urlToImage': 'https://i.insider.com/65162d1a98683c001946adfc?width=1200&format=jpeg',
#   'publishedAt': '2023-09-29T02:21:59Z',
#   'content': 'Former President Donald Trump and his wife, Melania Trump.Eva Marie Uzcategui/AFP via Getty Images\r\n<ul><li>Melania Trump is reportedly renegotiating the terms of her prenuptial agreement with Donald… [+3897 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Azmi Haroun',
#   'title': 'The crowds of Armenians fleeing Nagorno-Karabakh are so big you can see them from space',
#   'description': 'At least 70,000 refugees have fled Nagorno-Karabakh in the last week, leaving a traffic jam between Azerbaijan and Armenia that is visible from space.',
#   'url': 'https://www.businessinsider.com/cowds-of-armenians-fleeing-nagorno-karabakh-are-visible-from-space-2023-9',
#   'urlToImage': 'https://i.insider.com/65162723c50dce0019136729?width=1200&format=jpeg',
#   'publishedAt': '2023-09-29T02:18:18Z',
#   'content': 'Satellite imagery from September 26, 2023, shows the exodus of Armenian refugees from the Nagorno-Karabakh (NKAO) region, headed into ArmeniaSatellite image ©2023 Maxar Technologies\r\n<ul>\n<li>At leas… [+3467 chars]'},
#  {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#   'author': 'Jeanne Whalen',
#   'title': 'UAW to widen strike today barring progress in contract talks',
#   'description': 'The United Auto Workers union said it will broaden its strike at noon today, unless there is last-minute progress in contract talks with Detroit’s Big Three automakers.',
#   'url': 'https://www.washingtonpost.com/business/2023/09/28/uaw-strike-updates/',
#   'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/4QUTF6JQY54MFNFEKG6K5UJXUA_size-normalized.jpg&w=1440',
#   'publishedAt': '2023-09-29T01:23:37Z',
#   'content': 'Comment on this story\r\nComment\r\nThe United Auto Workers union said it will broaden its strike at noon Friday unless there is last-minute progress in contract talks with Detroits Big Three automakers.… [+4815 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'insider@insider.com (Sebastian Cahill)',
#   'title': 'The Russian culture ministry is blaming a pirated version of the Barbie movie for weakening nationwide values',
#   'description': 'A Russian politician is criticizing the "Barbie" movie for not promoting "traditional Russian values."',
#   'url': 'https://www.businessinsider.com/russia-culture-ministry-barbie-vladimir-putin-media-ukraine-war-2023-9',
#   'urlToImage': 'https://i.insider.com/6515e54298683c001946a592?width=1200&format=jpeg',
#   'publishedAt': '2023-09-29T01:00:26Z',
#   'content': 'As Russian citizens struggle to maintain morale during the ongoing invasion of Ukraine, the Russian Culture Ministry is taking a shot at the "Barbie" movie as a representation of hated Western ideolo… [+1476 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Erin Snodgrass',
#   'title': "Ukraine's relentless targeting of the Black Sea Fleet has disrupted Russia's efforts to block a key export",
#   'description': 'Heightened tensions in the Black Sea come two months after Russia pulled out of a UN-brokered deal that allowed Ukraine to continue exporting grain.',
#   'url': 'https://www.businessinsider.com/ukraine-attacks-russia-black-sea-fleet-support-grain-exports-2023-9',
#   'urlToImage': 'https://i.insider.com/6515fabe98683c001946aaab?width=1200&format=jpeg',
#   'publishedAt': '2023-09-29T00:22:07Z',
#   'content': 'Starting on June 26, Russia completely stopped registering new ships to enter Ukrainian ports as part of the Black Sea Grain Initiative.Yulii Zozulia / Ukrinform/Future Publishing via Getty Images\r\n<… [+3992 chars]'},
#  {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#   'author': 'Anumita Kaur',
#   'title': 'Tesla sued by federal gov for racial harassment, racist graffiti, slurs',
#   'description': 'The Equal Employment Opportunity Commission has alleged that Elon Musk’s electric vehicle company allowed racial harassment to run rampant in its workplace.',
#   'url': 'https://www.washingtonpost.com/business/2023/09/28/tesla-federal-lawsuit-racial-harassment/',
#   'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/PHPZSDYLRVZ4GY2SAQZ4TJKLUA_size-normalized.jpg&w=1440',
#   'publishedAt': '2023-09-29T00:18:50Z',
#   'content': 'Comment on this story\r\nComment\r\nElon Musks electric vehicle company Tesla allowed racial harassment of its Black employees to run rampant at its Fremont, Calif., plant and retaliated against some wor… [+3346 chars]'},
#  {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#   'author': 'Leigh Ann Caldwell',
#   'title': 'Hardliners plot to replace McCarthy with one of his deputies as shutdown looms',
#   'description': 'Such a move would throw the chamber into further disarray in the middle of a potential government shutdown.',
#   'url': 'https://www.washingtonpost.com/politics/2023/09/28/kevin-mccarthy-tom-emmer-government-shutdown-motion-vacate/',
#   'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/FKWCRKTN5REQNMO5RDSDU6IOTI.JPG&w=1440',
#   'publishedAt': '2023-09-29T00:17:57Z',
#   'content': 'Comment on this story\r\nComment\r\nA contingent of far-right House Republicans are plotting an attempt to remove Kevin McCarthy as House speaker as early as next week, a move that would throw the chambe… [+10672 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Ben Bergman',
#   'title': "Was Linda Yaccarino 'sandbagged?' What happened behind the scenes at the X CEO's disastrous coming out party.",
#   'description': "When Linda Yaccarino watched a live video feed of Yoel Roth's interview less than two hours before she was scheduled to take the stage she was horrified.",
#   'url': 'https://www.businessinsider.com/behind-the-scenes-at-linda-yaccarinos-disastrous-coming-out-party-2023-9',
#   'urlToImage': 'https://i.insider.com/6515e56a98683c001946a5b4?width=1200&format=jpeg',
#   'publishedAt': '2023-09-28T23:44:42Z',
#   'content': "CNBC's Julia Boorstin and X CEO Linda YaccarinoJerod Harris/Getty Images for Vox Media\r\n<ul>\n<li>X CEO Linda Yaccarino appeared rattled during her most high-profile appearance to date.</li>\n<li>Yoel … [+8589 chars]"},
#  {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#   'author': 'Hannah Knowles',
#   'title': '‘Baby steps aren’t going to cut it’: Debates do little to dent Trump dominance',
#   'description': 'Once seen as GOP candidates’ best chance at a game-changing moment, the showdowns have reinforced Trump’s advantage in the eyes of many Republicans.',
#   'url': 'https://www.washingtonpost.com/politics/2023/09/28/republicans-debate-trump-presidential-desantis-haley/',
#   'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/FGZY37BBUUQA45I62XPBTAYONA.JPG&w=1440',
#   'publishedAt': '2023-09-28T23:43:46Z',
#   'content': 'Comment on this story\r\nComment\r\nNikki Haley delivered the nights most memorable zinger. Nonconfrontational Tim Scott went on the offensive. Ron DeSantis came out swinging at an absent Donald Trump an… [+9615 chars]'},
#  {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#   'author': 'Lisa Rein',
#   'title': 'The IRS thought it was shutdown-proof. Now most staff would go home.',
#   'description': 'The IRS will furlough roughly 60,000 employees after a ruling that it cannot use funds from the Inflation Reduction Act to keep business going during a shutdown.',
#   'url': 'https://www.washingtonpost.com/politics/2023/09/28/irs-shutdown-furlough-inflation-act/',
#   'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/W4B3K2N3QAMDZQNMORJGM6ZW7A_size-normalized.jpg&w=1440',
#   'publishedAt': '2023-09-28T22:51:48Z',
#   'content': 'Comment on this story\r\nComment\r\nThe Internal Revenue Service and its roughly 90,000 employees hadexpected to weather the impending government shutdown by staying open for business, thanks to the $80 … [+7409 chars]'},
#  {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#   'author': 'Jeremy Barr',
#   'title': 'Second Republican debate averages 9.5 million viewers',
#   'description': 'The debate, aired on Fox News, Fox Business and Univision, was the most-watched show on television Wednesday though it drew fewer viewers than the first debate.',
#   'url': 'https://www.washingtonpost.com/style/media/2023/09/28/second-republican-debate-averages-95-million-viewers/',
#   'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/SXJGGGHNMRKLDZO43KX5GNMONQ.JPG&w=1440',
#   'publishedAt': '2023-09-28T22:50:12Z',
#   'content': 'Comment on this story\r\nComment\r\nThe second debate of the 2024 Republican presidential primary season attracted an average of 9.5 million viewers across the three channels that aired it Wednesday nigh… [+2045 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Michael Peck',
#   'title': 'As Ukraine and Russia burn through artillery shells, the US Army is looking for new highly precise rounds to fire from its extra-long-range cannons',
#   'description': "The emergence of artillery as the dominant weapon in Ukraine has only added urgency to the US Army's plans to upgrade its big guns.",
#   'url': 'https://www.businessinsider.com/us-army-looking-for-new-long-range-precision-artillery-ammunition-2023-9',
#   'urlToImage': 'https://i.insider.com/63385dbe6427060019eefaf4?width=1200&format=jpeg',
#   'publishedAt': '2023-09-28T22:23:01Z',
#   'content': 'A Copperhead laser-guided anti-tank 155 mm round striking in a test in February 1984.US Army\r\n<ul>\n<li>Artillery has been one of the most heavily used weapons by both Russia and Ukraine.</li>\n<li>The… [+5635 chars]'},
#  {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#   'author': 'Aaron Blake',
#   'title': 'Trump’s latest undemocratic move: calling to end debates',
#   'description': 'The former president is the clear front-runner, but three-quarters of GOP voters say they’re at least considering voting for someone else.',
#   'url': 'https://www.washingtonpost.com/politics/2023/09/28/trumps-latest-undemocratic-move-calling-end-debates/',
#   'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/OTGQ6ATULEMENYLCJGNVK4WPUM.jpg&w=1440',
#   'publishedAt': '2023-09-28T22:07:43Z',
#   'content': 'Comment on this story\r\nComment\r\nDonald Trumps opponents at Wednesday nights Republican presidential debate reserved their harshest attacks for his failure to participate. Trumps response: a call for … [+3988 chars]'},
#  {'source': {'id': 'the-wall-street-journal',
#    'name': 'The Wall Street Journal'},
#   'author': 'wsj',
#   'title': 'Xi-Biden Summit Soon?',
#   'description': 'Governments discuss Washington visits by a senior Chinese economic-policy official and the foreign minister',
#   'url': 'https://www.wsj.com/world/china/u-s-china-talks-gather-momentum-paving-way-for-xi-biden-summit-8db7d00a',
#   'urlToImage': 'https://images.wsj.net/im-859078/social',
#   'publishedAt': '2023-09-28T22:00:03Z',
#   'content': 'WSJ News Exclusive | U.S., China Talks Gain Momentum, Paving Way for Xi-Biden SummitBy , and Updated Sept. 28, 2023 11:32 am ET\r\nCommerce Secretary Gina Raimondo is the third cabinet member to visit … [+1016 chars]'},
#  {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#   'author': 'Yvonne Wingett Sanchez',
#   'title': 'Kari Lake plans to announce Senate run next month',
#   'description': 'Lake, a Trump ally, still has not conceded her defeat in last year’s Arizona gubernatorial race.',
#   'url': 'https://www.washingtonpost.com/politics/2023/09/28/lake-senate-arizona/',
#   'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/OGK5DTE365MHCV4LQQDNU3PULU_size-normalized.jpg&w=1440',
#   'publishedAt': '2023-09-28T21:46:34Z',
#   'content': 'Comment on this story\r\nComment\r\nKari Lake, an Arizona ally of former president Donald Trump who has not conceded her defeat to a Democrat during last years gubernatorial race, will enter the race for… [+4333 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Jenny McGrath',
#   'title': "Photos show the 3.86 billion-mile journey of OSIRIS-REx's asteroid sample mission from start to finish",
#   'description': "NASA's OSIRIS-REx traveled almost 4 billion miles to get a sample of the asteroid Bennu. Scientists hope to learn about our solar system's origins.",
#   'url': 'https://www.businessinsider.com/photos-nasa-osiris-rex-asteroid-sample-start-to-finish-2023-9',
#   'urlToImage': 'https://i.insider.com/6515dac3c50dce0019135ac5?width=1200&format=jpeg',
#   'publishedAt': '2023-09-28T21:42:39Z',
#   'content': "Artist's illustration of NASA's OSIRIS-REx probe sampling an asteroid.Lockheed Martin\r\n<ul>\n<li>NASA's OSIRIS-REx has been traveling for seven years to get an asteroid sample to Earth.</li>\n<li>It la… [+4835 chars]"},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Quentyn Kennemer',
#   'title': 'How to watch Lions vs. Packers: Free Thursday Night Football live stream',
#   'description': 'Looking to stream the Lions vs. Packers game? These free live streams for Thursday Night Football will get you settled before kickoff.',
#   'url': 'https://www.businessinsider.com/guides/streaming/how-to-watch-lions-vs-packers-free-live-stream-09-2023',
#   'urlToImage': 'https://i.insider.com/651490b2eee46600193bb098?width=1200&format=jpeg',
#   'publishedAt': '2023-09-28T21:15:01Z',
#   'content': 'Packers and Lions fight for the throne in the north on Thursday Night Football.Rey Del Rio/Stringer (Left), Patrick McDermott (Right) / Getty Images\r\nWhen you buy through our links, Insider may earn … [+6527 chars]'},
#  {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#   'author': 'Rachel Siegel',
#   'title': 'The saga of Sen. Bob Menendez',
#   'description': 'Stacks of cash, a Mercedes-Benz convertible and arms sales to Egypt – they’re all in the details of the federal indictment against Sen. Bob Menendez. This week, the New Jersey Democrat pleaded not guilty. So what’s next for the embattled senator?',
#   'url': 'https://www.washingtonpost.com/podcasts/post-reports/the-saga-of-sen-bob-menendez/?utm_source=rss&utm_medium=referral&utm_campaign=wp_politics',
#   'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https%3A%2F%2Fpodcast.posttv.com%2Fseries%2F20230928%2Ft_1695934828907_name_FFTYWOCV7BGERNRLC3PNJU6QYI.jpg&w=1400',
#   'publishedAt': '2023-09-28T21:03:15Z',
#   'content': 'The indictments against Sen. Bob Menendez and his wife are stunning, with investigators finding envelopes filled with cash and gold bars in the senators home. It is considered one of the more serious… [+369 chars]'},
#  {'source': {'id': 'the-wall-street-journal',
#    'name': 'The Wall Street Journal'},
#   'author': 'wsj',
#   'title': 'China Investing Billions in Global Disinformation Campaign...',
#   'description': 'Fake authors, bot armies and lawsuits are among the tactics Beijing employs to reshape the information landscape',
#   'url': 'https://www.wsj.com/world/china/china-is-investing-billions-in-global-disinformation-campaign-u-s-says-88740b85',
#   'urlToImage': 'https://images.wsj.net/im-859742/social',
#   'publishedAt': '2023-09-28T21:00:03Z',
#   'content': 'China Is Investing Billions in Global Disinformation Campaign, U.S. SaysBy and Sept. 28, 2023 2:15 pm ET\r\nWASHINGTON—The Chinese government is pouring billions of dollars annually into a global campa… [+876 chars]'},
#  {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#   'author': 'Eva Dou',
#   'title': 'Ken Paxton sues Yelp over abortion notice on crisis pregnancy centers',
#   'description': 'Texas AG Ken Paxton’s lawsuit argues Yelp appended “misleading” labels to the facilities, which aim to dissuade women from having abortions',
#   'url': 'https://www.washingtonpost.com/technology/2023/09/28/ken-paxton-yelp-lawsuit-abortion-pregnancy/',
#   'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/4F54CLXY5JATPGBZCME2XOIRB4.jpg&w=1440',
#   'publishedAt': '2023-09-28T20:59:47Z',
#   'content': 'Comment on this story\r\nComment\r\nTexas Attorney General Ken Paxton sued Yelp on Thursday, alleging the review platforms labeling of crisis pregnancy centers, facilities that aim to dissuade women from… [+4705 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Chris Panella,Ryan Pickrell',
#   'title': 'Tank duels of the kind the Abrams was built for are rare in Ukraine, where very few tanks are actually killed in fights with enemy armor',
#   'description': 'In Ukraine, the newly arrived M1 Abrams tanks may have less opportunity to do what they do best.',
#   'url': 'https://www.businessinsider.com/tanks-duels-the-abrams-was-built-for-rare-in-ukraine-2023-9',
#   'urlToImage': 'https://i.insider.com/6515917a98683c0019468735?width=1200&format=jpeg',
#   'publishedAt': '2023-09-28T20:58:49Z',
#   'content': 'U.S. Army M1/A1 Abrams tanks from Charlie company of the 464 Armored Battalion are deployed during task force maneuvers on December 18, 2002, near the Iraqi border in the Kuwaiti.Scott Nelson/Getty I… [+5169 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Maiya Focht',
#   'title': 'A group of bull sharks lived in a golf course pond for 17 years. Scientists say they could be in other ponds in Australia',
#   'description': "Six bull sharks lived in a golf course pond for half their lives. Scientists said it's the longest they've ever seen the species live in fresh water.",
#   'url': 'https://www.businessinsider.com/bull-sharks-can-survive-freshwater-lived-pond-17-years-2023-9',
#   'urlToImage': 'https://i.insider.com/6515e78c98683c001946a6b7?width=1200&format=jpeg',
#   'publishedAt': '2023-09-28T20:52:59Z',
#   'content': 'The bull sharks found in Carbrook Country Club lived for over half a bull sharks expected life span.Getty Images\r\n<ul>\n<li>A group of bull sharks lived in a freshwater golf course pond for over 17 ye… [+3627 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Lilian Manansala,Tamara Lindstrom',
#   'title': "Dumbo octopus 'wows' researchers during deep-sea expedition",
#   'description': "Sightings of dumbo octopuses are rare, so researchers were enthralled when one appeared on their submersible's camera on a deep-sea dive near Hawaii.",
#   'url': 'https://www.businessinsider.com/dumbo-octopus-eara-animal-deep-sea-rare-sighting-submersible-ocean-2023-9',
#   'urlToImage': 'https://i.insider.com/6515e0f7c50dce0019135d2a?width=1200&format=jpeg',
#   'publishedAt': '2023-09-28T20:42:59Z',
#   'content': "Sightings of dumbo octopuses are rare, so researchers were enthralled when one appeared on their submersible's camera on a deep-sea dive near Hawaii.\xa0 \xa0\xa0Read the original article on Business Insider"},
#  {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#   'author': 'Chris Velazco',
#   'title': 'The iPhone 15 Pro overheats, say some new owners',
#   'description': 'Shortly after the iPhone 15 Pro and 15 Pro Max were released on Sept. 22, users across the world began reporting that the devices could become uncomfortably warm during use.',
#   'url': 'https://www.washingtonpost.com/technology/2023/09/28/iphone-15-pro-overheating/',
#   'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/KVJNK435MTOB6F3Q7NB5ULRFFM_size-normalized.jpg&w=1440',
#   'publishedAt': '2023-09-28T20:42:22Z',
#   'content': 'Comment on this story\r\nComment\r\nApples iPhone 15 Pro is the hot new thing but not in a good way.\r\nShortly after the iPhone 15 Pro and 15 Pro Max were released on Sept. 22, users across the world bega… [+3791 chars]'},
#  {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#   'author': 'Steven Goff',
#   'title': 'D.C. United facing a ‘must-win situation’ as playoff hopes fade',
#   'description': 'After squandering opportunity after opportunity at home to build its postseason portfolio, United is desperate for points in Vancouver and Austin.',
#   'url': 'https://www.washingtonpost.com/sports/2023/09/28/dc-united-playoff-hopes/',
#   'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/QIWNOCMV5PXKMTMNQWC7CI2UTI.jpg&w=1440',
#   'publishedAt': '2023-09-28T20:39:35Z',
#   'content': 'Comment on this story\r\nComment\r\nD.C. United boarded a charter Thursday for the last and most taxing trip of the season, a seven-day adventure that will determine whether the MLS playoffs remain withi… [+4465 chars]'},
#  {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#   'author': 'Philip Bump',
#   'title': 'The rise of ‘Chinese Communist Party’ as a pejorative',
#   'description': 'It became popular during the pandemic —\xa0and has kept up momentum since.',
#   'url': 'https://www.washingtonpost.com/politics/2023/09/28/desantis-republicans-china-ccp/',
#   'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/XJWNXE4SRNX6KNNCY4LQGH6IKU.JPG&w=1440',
#   'publishedAt': '2023-09-28T20:39:04Z',
#   'content': 'Comment on this story\r\nComment\r\nFlorida Gov. Ron DeSantiss (R) bid for the 2024 Republican presidential nomination began with a focus on one specific word: Fauci.\r\nDont Fauci my Florida gear went on … [+4489 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'dreuter@insider.com (Dominick Reuter)',
#   'title': "Little Caesars knows what you're going to order before you do. With AI tools, soon more restaurants will.",
#   'description': 'Restaurant brands are increasingly stepping up their use of AI to predict customer demand and improve the speed and accuracy of service.',
#   'url': 'https://www.businessinsider.com/ai-helping-restaurants-little-caesars-forecast-customer-demand-2023-9',
#   'urlToImage': 'https://i.insider.com/6515e15a98683c001946a400?width=1200&format=jpeg',
#   'publishedAt': '2023-09-28T20:31:33Z',
#   'content': 'Normally it takes about 10 minutes to cook a pizza, but Little Caesars customers can now grab a fresh one in less time than they may have spent waiting for someone to answer the phone to take their o… [+4151 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'prosen@insider.com (Phil Rosen)',
#   'title': 'US stocks climb as bond yields slip from 16-year highs',
#   'description': 'The Dow gained over 100 points, while the S&P 500 and the Nasdaq edged higher amid a decline in key bond yields.',
#   'url': 'https://markets.businessinsider.com/news/stocks/stock-market-news-indexes-bond-yields-treasury-fed-jobs-labor-2023-9',
#   'urlToImage': 'https://i.insider.com/63adf96e3e42ed001855e273?width=1200&format=jpeg',
#   'publishedAt': '2023-09-28T20:08:06Z',
#   'content': 'US stocks closed in the green on Thursday as bond yields retreated from multi-year highs.\r\nInvestors pushed stocks higher as they try to rebound from steep losses in the month. The 10-year US Treasur… [+970 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Sabina Wex',
#   'title': "AI sensors and WiFi networks that provide workplace insights are antidotes for some companies combating 'zombie offices'",
#   'description': "With office spaces being emptier, companies are using WiFi access points and AI sensors to learn about employees' behavior in the workplace.",
#   'url': 'https://www.businessinsider.com/office-spaces-empty-ai-sensors-wifi-network-optimization-2023-9',
#   'urlToImage': 'https://i.insider.com/6514852d1c099d0019ad4a09?width=1200&format=jpeg',
#   'publishedAt': '2023-09-28T19:55:01Z',
#   'content': '.insider-raw-embed + p { display: none; }\r\n\n // put series title here\n const seriesTitle = "Build IT";\n // put sponsor text here\n const text = "Presented by";\n // put the viking id for the image here… [+10843 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'trains@insider.com (Taylor Rains)',
#   'title': "British Airways' new pilot and flight attendant uniforms are here. See the new look and how it's changed over the decades.",
#   'description': "A dress, skirt, trouser suit, and jumpsuit make up the women's wardrobe, while a three-piece suit is available for men. The upgrades are the first in 20 years.",
#   'url': 'https://www.businessinsider.com/see-british-airways-brand-new-pilot-and-flight-attendant-uniforms-2023-9',
#   'urlToImage': 'https://i.insider.com/65147ad9eee46600193ba936?width=1200&format=jpeg',
#   'publishedAt': '2023-09-28T19:41:12Z',
#   'content': 'British Airways has a new look for the first time in 20 years \xa0\r\nAfter first teasing the new garb in January, the London-based airline finally released its new pilot and flight attendant uniforms on … [+521 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'ericadomena@gmail.com (Erica Star Domena,Tamara Lindstrom)',
#   'title': 'Chaos reigns at GOP debate as Trump skips out',
#   'description': 'The second Republican presidential debate featured a barrage of slights against Donald Trump and chaos for the Fox moderators. But Trump stayed away.',
#   'url': 'https://www.businessinsider.com/election-republican-debate-trump-chris-christie-ramaswamy-simi-gop-president-2023-9',
#   'urlToImage': 'https://i.insider.com/6515c7eac50dce0019135496?width=1200&format=jpeg',
#   'publishedAt': '2023-09-28T19:39:22Z',
#   'content': 'The second Republican presidential debate featured a barrage of comments against Donald Trump and chaos for the Fox moderators. But Trump himself stayed away.'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'jsor@insider.com (Jennifer Sor)',
#   'title': "Oil prices will hit $100 a barrel in 2024, Goldman Sachs' chief commodities strategist warns",
#   'description': "Oil is in a new supercycle, as chronic undersupply will take crude prices into the triple digits, Goldman Sachs' Jeff Currie warned.",
#   'url': 'https://markets.businessinsider.com/news/commodities/oil-prices-outlook-brent-wti-rally-supply-shortage-goldman-sachs-2023-9',
#   'urlToImage': 'https://i.insider.com/5ea01e06a2fd914eb643f983?width=1200&format=jpeg',
#   'publishedAt': '2023-09-28T19:37:56Z',
#   'content': "Oil prices are heading into the triple-digits next year, as a supercycle lifts the commodities sector, according to Goldman Sachs' outgoing commodities chief Jeff Currie.\r\nBrent crude, the internatio… [+1416 chars]"},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Katie Hawkinson',
#   'title': "Ukraine's air force shot down 34 Iran-made Shahed drones overnight, officials say",
#   'description': "Russia has used Iran's Shahed-136 drones previously in Ukraine to devastating effect and has ramped up production of its own version at home.",
#   'url': 'https://www.businessinsider.com/ukraine-air-force-shot-down-iran-made-shahed-136-drones-2023-9',
#   'urlToImage': 'https://i.insider.com/65159db698683c0019468bf9?width=1200&format=jpeg',
#   'publishedAt': '2023-09-28T19:33:31Z',
#   'content': "Russia has used Iran-made Shahed-136 drones to launch devastating attacks on cities in Ukraine over the last year.Global Images Ukraine/Getty Images\r\n<ul>\n<li>Ukraine's air force shot down 34 Russian… [+2017 chars]"},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Catherine Boudreau',
#   'title': 'Help wanted: More female electricians to help America hit its climate goals',
#   'description': 'Female electricians are integral to helping the climate crisis. Attracting more women and diversity into the electrician trade is key to the US green-energy transition.',
#   'url': 'https://www.businessinsider.com/female-electricians-helping-to-set-climate-goals-help-economy-2023-9',
#   'urlToImage': 'https://i.insider.com/6515d41398683c0019469f02?width=1200&format=jpeg',
#   'publishedAt': '2023-09-28T19:29:45Z',
#   'content': 'Only 2% of electricians are women and nearly 80% are white, federal data shows.Amorn Suriyan/Getty Images\r\n<ul><li>The US needs more electricians to install\xa0renewable energy and electric vehicle char… [+3300 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Phil Rosen',
#   'title': "Here's why the stock market could be primed for a year-end rally",
#   'description': 'Times of extreme pessimism in the stock market are often followed by a period of gains, analysts at Ned Davis Research said.',
#   'url': 'https://markets.businessinsider.com/news/stocks/stock-market-outlook-rally-ned-davis-research-economy-fed-sentiment-2023-9',
#   'urlToImage': 'https://i.insider.com/5f7b21e7282c500018c78872?width=1200&format=jpeg',
#   'publishedAt': '2023-09-28T19:25:23Z',
#   'content': 'Traders work on the floor at the New York Stock Exchange (NYSE) in New York, U.S., March 2, 2020.Brendan McDermid/Reuters\r\n<ul>\n<li>The stock market has slumped in August and September, but Ned Davis… [+2530 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Sarah Jackson',
#   'title': "Elon Musk's biographer says X CEO's rocky interview was 'not a pretty sight' but she's 'the right person' for the job",
#   'description': 'Musk\'s biographer, Walter Isaacson, said it\'ll be "interesting" to see X under Linda Yaccarino\'s leadership and described her as "an impulsive hire."',
#   'url': 'https://www.businessinsider.com/walter-isaacson-x-ceo-linda-yaccarino-interview-2023-9',
#   'urlToImage': 'https://i.insider.com/6513e76c1c099d0019ad25dc?width=1200&format=jpeg',
#   'publishedAt': '2023-09-28T19:16:54Z',
#   'content': 'X CEO Linda Yaccarino still has the support of Elon Musk\'s biographer, who says she\'s "the right person" for the job, though he admits her Code Conference interview was "not a pretty sight."Isaac Bre… [+4966 chars]'},
#  {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#   'author': 'Scott Clement',
#   'title': 'Our Republican debate poll shows a largely unchanged race',
#   'description': 'A 538/Washington Post/Ipsos poll surveyed likely Republican voters before and after the debate.',
#   'url': 'https://www.washingtonpost.com/politics/2023/09/28/poll-republican-presidential-debate/',
#   'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/5I6A5PGAQNFC5KLKOIAMT2SJAY.png&w=1440',
#   'publishedAt': '2023-09-28T19:00:09Z',
#   'content': 'Comment on this story\r\nComment\r\nNearly 1 in 3 potential Republican primary voters watched the debate Wednesday at the Ronald Reagan Presidential Library in California, but the performance of the cand… [+3602 chars]'},
#  {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#   'author': 'Carolyn Hax, Haben Kelati',
#   'title': 'My remarried ex keeps pushing for news on my love life. Give advice to this Hax question.',
#   'description': 'Every week, we ask readers to think like an advice columnist and submit their advice to a question Carolyn Hax hasn’t answered.',
#   'url': 'https://www.washingtonpost.com/advice/2023/09/28/carolyn-hax-ex-questions-about-love-life/',
#   'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/RNKZGCR5GEI65LX5IDADTKCVXI.jpg&w=1440',
#   'publishedAt': '2023-09-28T19:00:00Z',
#   'content': 'Carolyn Hax cant get to every question she receives, so every week we ask readers to think like an advice columnist and submit their guidance. Out of the many great responses we receive, we select a … [+503 chars]'},
#  {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#   'author': 'Maegan Vazquez',
#   'title': 'Menendez remains defiant after meeting with Senate Democrats',
#   'description': 'The New Jersey senator once again signaled that he does not plan to step down despite growing calls to resign amongst his Democratic colleagues.',
#   'url': 'https://www.washingtonpost.com/politics/2023/09/28/menendez-schumer-senate-democrats/',
#   'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/SCFBGBCJTTZJHLUP6XCHNIQZXU_size-normalized.JPG&w=1440',
#   'publishedAt': '2023-09-28T18:51:15Z',
#   'content': 'Comment on this story\r\nComment\r\nSen. Bob Menendez (D-N.J.) signaled again on Thursday that he does not plan to resign from the U.S. Senate, even as a majority of Senate Democrats have now called on h… [+2625 chars]'},
#  {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#   'author': 'Philip Bump',
#   'title': 'Jim Jordan’s dishonest argument of wrongdoing by Biden',
#   'description': 'In the first hearing of the impeachment inquiry, Rep. Jim Jordan made sweeping —\xa0and debunked —\xa0claims about President Biden.',
#   'url': 'https://www.washingtonpost.com/politics/2023/09/28/jordan-biden-impeachment-hearing/',
#   'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/CN7NMGRA3WENJ7VD3DGYC2KLOI_size-normalized.jpg&w=1440',
#   'publishedAt': '2023-09-28T18:47:32Z',
#   'content': 'Comment on this story\r\nComment\r\nRep. Jim Jordan (R-Ohio) has a well-honed persona that he presents on Capitol Hill. He wears a suit jacket as infrequently as possible, a performative demonstration of… [+9426 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'ssheth@businessinsider.com (Sonam Sheth)',
#   'title': "Russian troops have put up dozens of surveillance towers across Mariupol to track Ukrainians' conversations and digital activity",
#   'description': '"Old Orwell would simply be amazed how all his fictions became the reality of Mariupol," an advisor to Mariupol\'s exiled mayor wrote on Telegram.',
#   'url': 'https://www.businessinsider.com/russia-mariupol-surveillance-towers-track-ukrainians-2023-9',
#   'urlToImage': 'https://i.insider.com/64e484b1bd98a600197ba4b9?width=1200&format=jpeg',
#   'publishedAt': '2023-09-28T18:36:13Z',
#   'content': "Russian troops have installed dozens of towers across the occupied city of Mariupol to surveil Ukrainian citizens' conversations and track their digital activity, Petro Andryushchenko, an advisor to … [+1800 chars]"},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'asoni@insider.com (Aruni Soni)',
#   'title': 'Pending home sales plunged in August as 2-decade high mortgage rates continue to squeeze both buyers and sellers',
#   'description': "Pending home sales slipped to 7.1% in August. It's the latest sign of a deepening freeze in the market as mortgage rates and prices stay high.",
#   'url': 'https://markets.businessinsider.com/news/commodities/pending-home-sales-plunged-august-decade-high-mortgage-rates-buyers-2023-9',
#   'urlToImage': 'https://i.insider.com/6515c25dc50dce0019135246?width=1200&format=jpeg',
#   'publishedAt': '2023-09-28T18:35:08Z',
#   'content': 'Pending home sales slipped 7.1% in August compared to July, according to the National Association of Realtors.\r\nThe decline comes as mortgage rates push well above 7% this quarter, keeping borrowing … [+1299 chars]'},
#  {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#   'author': 'Mariana Alfaro',
#   'title': 'Senate Republicans in discussions to add border security to stopgap bill',
#   'description': 'The parties have rarely been able to find consensus around the border-patrol issue.',
#   'url': 'https://www.washingtonpost.com/politics/2023/09/28/government-shutdown-house-senate-funding-bill/',
#   'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/IEHTKNYORQ47SVBCYRJP2XESDY_size-normalized.JPG&w=1440',
#   'publishedAt': '2023-09-28T18:31:43Z',
#   'content': 'Comment on this story\r\nComment\r\nMembers of the House and Senate are discussing adding border security provisions to a short-term funding bill in hopes of getting enough House Republican support to av… [+5525 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Bryan Metzger',
#   'title': "GOP Senate candidate Dave McCormick drops 'pro-life' rhetoric from his website as party strategists urge shift on abortion messaging",
#   'description': 'McCormick\'s campaign argued it would be "ridiculous" to conclude that the change was about abortion, citing a total overhaul of the website.',
#   'url': 'https://www.businessinsider.com/dave-mccormick-pro-life-website-section-abortion-messaging-2023-9',
#   'urlToImage': 'https://i.insider.com/651581c05f0f350019c437a3?width=1200&format=jpeg',
#   'publishedAt': '2023-09-28T18:19:19Z',
#   'content': 'Pennsylvania GOP Senate Candidate Dave McCormick speaks at a campaign rally during his previous campaign in May 16, 2022.Michael M. Santiago/Getty Images\r\n<ul>\n<li>Dave McCormick struck an old "Issue… [+4838 chars]'},
#  {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#   'author': 'Taylor Lorenz',
#   'title': 'Democrats plan four-hour live-stream with Twitch and YouTube stars',
#   'description': 'The significance of the event may be what it says about the way Democrats and Republicans are seeking to engage with potential voters online.',
#   'url': 'https://www.washingtonpost.com/technology/2023/09/28/live-stream-twitch-politics-khanna/',
#   'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/RVFI4NCQF4I6TPNXIT4URTAGAU.jpg&w=1440',
#   'publishedAt': '2023-09-28T18:10:42Z',
#   'content': 'Comment on this story\r\nComment\r\nOn Friday morning, Rep. Ro Khanna (D-Calif.) will kick off a four-hour live stream from a Washington D.C. rooftop overlooking the White House with some of the biggest … [+4679 chars]'},
#  {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#   'author': 'Barry Svrluga',
#   'title': 'The Nationals’ core is developing. The next step: Finding a star.',
#   'description': 'The most intriguing part of the Washington Nationals’ rebirth will be figuring out who the next face of the franchise will be.',
#   'url': 'https://www.washingtonpost.com/sports/2023/09/28/washington-nationals-star-face-franchise/',
#   'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/JIOE2H4UGZEQBE5H323JSOIIUQ.jpg&w=1440',
#   'publishedAt': '2023-09-28T18:05:45Z',
#   'content': 'Comment on this story\r\nComment\r\nWhatever happens over the weekend in Atlanta, where the juggernaut Braves are a model any other franchise wouldnt mind copying, the Washington Nationals 2023 season wi… [+6744 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Filip De Mott',
#   'title': 'Home ownership is now unaffordable in 80% of US counties as costs eat up a bigger share of pay',
#   'description': 'Amid rising home prices and mortgages rates, ownership costs now suck up 35% of average wages, ATTOM said.',
#   'url': 'https://markets.businessinsider.com/news/stocks/housing-market-home-prices-ownership-costs-unaffordable-mortgage-payments-wages-2023-9',
#   'urlToImage': 'https://i.insider.com/6515a0a7c50dce00191346d6?width=1200&format=jpeg',
#   'publishedAt': '2023-09-28T17:53:20Z',
#   'content': 'Oregon lawmakers want to make it easier to remove racist language from house deeds.VisualField via Getty Images\r\n<ul>\n<li>Home-ownership expenses are now unaffordable in 79% of US counties, ATTOM rep… [+2476 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Jordan Hart',
#   'title': "Phone calls might be dying — but they're still alive at work. Here's how etiquette experts say you should handle them.",
#   'description': 'Should you send a work colleague a warning text before calling them on the phone? Probably so, experts say.',
#   'url': 'https://www.businessinsider.com/work-phone-call-etiquette-expert-send-warning-text-first-2023-9',
#   'urlToImage': 'https://i.insider.com/65147f981c099d0019ad47e3?width=1200&format=jpeg',
#   'publishedAt': '2023-09-28T17:50:37Z',
#   'content': "Phone calls are here to stay at work, but they should be saved for certain occasions, etiquette experts say.tomazl/Getty Images\r\n<ul><li>Etiquette experts say phone calls aren't going away at the off… [+3909 chars]"},
# ...
#   'url': 'https://apnews.com/article/officer-trial-elijah-mcclain-black-death-denver-9f976b1e4b9ae52bf824ae5b68ba6fb6',
#   'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/roanoke.com/content/tncms/assets/v3/editorial/a/9f/a9f10ba3-4082-5e13-affe-ee76583e5b32/650acd8857b46.image.jpg?crop=1763%2C926%2C0%2C124&resize=1200%2C630&order=crop%2Cresize',
#   'publishedAt': '2023-09-21T00:18:56Z',
#   'content': 'By COLLEEN SLEVIN - Associated Press\r\nBRIGHTON, Colo. (AP) Two Denver-area police officers who put Elijah McClain in a neck hold ignored his pleas of I cant breathe before the Black man was injected … [+6637 chars]'},
#  {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#   'author': 'By DAVID BILLER, JOSH BOAK and AAMER MADHANI - Associated Press',
#   'title': "Biden and Brazil's Lula focus on workers' rights while publicly playing down differences",
#   'description': 'President Joe Biden and his Brazilian counterpart, Luiz Inácio Lula da Silva, focused on workers’ rights as the leaders of the Western Hemisphere’s largest democracies met Wednesday in New York. They steered clear in public about their differences including U…',
#   'url': 'https://apnews.com/article/biden-lula-new-york-bilateral-labor-climate-dc95545492a4ae0bf4eb5f13a07758d7',
#   'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/roanoke.com/content/tncms/assets/v3/editorial/4/38/438940a0-4346-5ed5-bd84-befe68b7e1b0/650acd78c6718.image.jpg?crop=1763%2C926%2C0%2C124&resize=1200%2C630&order=crop%2Cresize',
#   'publishedAt': '2023-09-20T22:47:15Z',
#   'content': 'By DAVID BILLER, JOSH BOAK and AAMER MADHANI - Associated Press\r\nNEW YORK (AP) President Joe Biden and his Brazilian counterpart, Luiz Inácio Lula da Silva, played up their mutual affection for worke… [+6346 chars]'},
#  {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#   'author': 'AP',
#   'title': 'Key To The Metropolitan Opera’s Future: Contemporary Work',
#   'description': 'The Metropolitan Opera is broadening its repertoire this season by performing more recent operas alongside classics like “La Boheme.” This fall the company will stage “Dead Man Walking,” “X: The Life and Times of Malcolm X” and “Florencia en el Amazonas” — th…',
#   'url': 'https://apnews.com/article/met-opera-new-season-preview-8b0b793bb35dd73e57b8a3da52753b4f',
#   'urlToImage': 'https://dims.apnews.com/dims4/default/aaac683/2147483647/strip/true/crop/4200x2363+0+383/resize/1440x810!/quality/90/?url=https%3A%2F%2Fassets.apnews.com%2F92%2F99%2F6ec1163ee5be43173dbf71401400%2F5a51c7f20bac49a5b224fa8a380dca53',
#   'publishedAt': '2023-09-20T20:28:00Z',
#   'content': 'NEW YORK (AP) Jake Heggie recalls that after Dead Man Walking premiered in San Francisco in 2000, his first opera was quickly taken up by other companies, but there was not even a whisper of possibil… [+5672 chars]'},
#  {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#   'author': 'Alanna Durkin Richer',
#   'title': 'A 96-year-old federal judge is barred from hearing cases in a bitter fight over her mental fitness',
#   'description': "A 96-year-old U.S. federal appeals court judge has been barred from hearing cases for a year after a judicial panel said she refused to undergo medical testing over concerns she's no longer mentally fit to serve on the bench. Wednesday's development is the la…",
#   'url': 'https://apnews.com/article/judge-suspended-age-disability-federal-newman-afaa58f65bfd6612300ae5a925c7cc55',
#   'urlToImage': 'https://dims.apnews.com/dims4/default/50da055/2147483647/strip/true/crop/2982x1677+0+155/resize/1440x810!/quality/90/?url=https%3A%2F%2Fassets.apnews.com%2Fea%2F23%2F760b074bd969689995d90dcaea9f%2F7cae22c5fc1a44f78f62494647e3b6f6',
#   'publishedAt': '2023-09-20T19:49:12Z',
#   'content': 'A 96-year-old U.S. federal appeals court judge was barred Wednesday from hearing cases for a year after a panel said she refused to undergo medical testing amid concerns that she is no longer mentall… [+3650 chars]'},
#  {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#   'author': 'ap news',
#   'title': 'AG Garland takes hot seat in House hearing...',
#   'description': 'Attorney General Merrick Garland is set to come face-to-face with his most ardent critics. House Republicans are preparing to use a routine oversight hearing to interrogate Garland about what they claim is the “weaponization” of the Justice Department under P…',
#   'url': 'https://apnews.com/article/garland-justice-department-house-republicans-oversight-hearing-df70e290360cde444032f1b75343d941',
#   'urlToImage': 'https://dims.apnews.com/dims4/default/1e4b26b/2147483647/strip/true/crop/3918x2204+0+204/resize/1440x810!/quality/90/?url=https%3A%2F%2Fassets.apnews.com%2F3a%2Fa4%2F751f479b64fdcee0e29d2d4422be%2F10080a7227ce4feebba3f2a3611ae9fa',
#   'publishedAt': '2023-09-20T14:00:03Z',
#   'content': 'Attorney General Garland set to face his GOP critics as Justice Department is under heavy scrutinyWASHINGTON (AP) — Attorney General Merrick Garland on Wednesday is set to come face-to-face with his … [+5203 chars]'},
#  {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#   'author': 'ap news',
#   'title': 'Book bans hit record high...',
#   'description': 'The nationwide surge in book bannings continues. The American Library Association is reporting that challenges to books in schools and public libraries will likely reach record highs in 2023, topping what had been a record pace in 2022. School libraries had l…',
#   'url': 'https://apnews.com/article/books-bans-american-library-association-42b34a284a6363439de20bbb65bb43b4',
#   'urlToImage': 'https://dims.apnews.com/dims4/default/9f3d3b8/2147483647/strip/true/crop/5832x3281+0+304/resize/1440x810!/quality/90/?url=https%3A%2F%2Fassets.apnews.com%2F22%2F87%2F534dcaa6756f5f0a34f1da4c3188%2F105ab5a7053f47e1b90ab0d66d77bd72',
#   'publishedAt': '2023-09-20T13:00:03Z',
#   'content': 'Challenges to library books continue at record pace in 2023, American Library Association reportsNEW YORK (AP) — Book bans and attempted bans continue to hit record highs, according to the American L… [+4243 chars]'},
#  {'source': {'id': 'bloomberg', 'name': 'Bloomberg'},
#   'author': 'Bloomberg',
#   'title': 'HDFC Bank gets rare analyst downgrade on loan growth concerns',
#   'description': "HDFC Bank Ltd. shares fell 4.2% after Nomura Holdings Inc. downgraded the stock due to lowered revision of parent's business. Nomura analysts cited concerns over HDFC's return on assets and loan growth pressures. HDFC Bank merged with parent HDFC Ltd. in July…",
#   'url': 'https://www.bloomberg.com/news/articles/2023-09-20/hdfc-bank-gets-rare-analyst-downgrade-on-loan-growth-concerns',
#   'urlToImage': 'https://bl-i.thgim.com/public/incoming/vmqvrx/article67325880.ece/alternates/LANDSCAPE_1200/2023-04-21T112301Z_809828748_RC2YI0ANW80C_RTRMADP_3_INDIA-BANKS-HDFC-BANK.JPG',
#   'publishedAt': '2023-09-20T10:25:43Z',
#   'content': 'Shares of HDFC Bank Ltd. fell as much as 4.2 per cent after Nomura Holdings Inc. downgraded the stock, prompted by the lenders lowered revision of the business absorbed from its parent.\xa0\r\nThe downgra… [+1074 chars]'},
#  {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#   'author': 'The Associated',
#   'title': 'At least 6 Palestinians are killed in latest fighting with Israel, Palestinian health officials say',
#   'description': 'Palestinian health officials say the death toll over a day of fighting between Israel and the Palestinians in the occupied West Bank and the Gaza Strip has risen to six. Officials said on Wednesday that an Israeli military raid in a West Bank refugee camp kil…',
#   'url': 'https://apnews.com/article/israel-palestinians-killed-gaza-west-bank-0454cf65390d6d8c27ddb55d51a083c4',
#   'urlToImage': 'https://dims.apnews.com/dims4/default/40b02d4/2147483647/strip/true/crop/7270x4089+0+378/resize/1440x810!/quality/90/?url=https%3A%2F%2Fassets.apnews.com%2F56%2F1f%2Ffcf6ba84b3376fadf6a716f96955%2F63b56fcfe7af45448723842ebeb6e50e',
#   'publishedAt': '2023-09-20T06:02:12Z',
#   'content': 'TEL AVIV, Israel (AP) Israeli military operations in the occupied West Bank and unrest in the Gaza Strip have killed six Palestinians, Palestinian health officials said Wednesday, the latest spike in… [+3645 chars]'},
#  {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#   'author': 'AP',
#   'title': "Caitlin Clark of Iowa wins Sullivan Award as the nation's top collegiate athlete",
#   'description': 'Iowa basketball star Caitlin Clark has won the 93rd AAU James E. Sullivan Award as the nation’s top collegiate or Olympic athlete. Clark was honored at the New York Athletic Club. She was the consensus national player of the year…',
#   'url': 'https://apnews.com/article/caitlin-clark-iowa-sullivan-award-0d313fe31726c910dee5bc5e2d435341',
#   'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/stltoday.com/content/tncms/assets/v3/editorial/6/79/67992e09-e2bc-5014-a6c3-3a7fa9947628/650ac9c524f53.image.jpg?crop=1706%2C896%2C0%2C159&resize=1200%2C630&order=crop%2Cresize',
#   'publishedAt': '2023-09-20T04:04:00Z',
#   'content': "NEW YORK (AP) Iowa basketball star Caitlin Clark won the 93rd AAU James E. Sullivan Award on Tuesday night as the nation's top collegiate or Olympic athlete.\r\nClark was honored at the New York Athlet… [+1546 chars]"},
#  {'source': {'id': 'bloomberg', 'name': 'Bloomberg'},
#   'author': 'Bloomberg',
#   'title': 'Citigroup and BNP among banks exploring $15 billion Indian Ocean project',
#   'description': 'Banks incl. Citigroup, BNP Paribas, Standard Chartered, HSBC, Societe Generale & Rothschild & Co. are exploring financing options for a $15B program to protect Indian ocean habitats. The Great Blue Wall initiative has already raised $100M & a $200M project pr…',
#   'url': 'https://www.bloomberg.com/news/articles/2023-09-19/citi-bnp-among-banks-exploring-15-billion-indian-ocean-project',
#   'urlToImage': 'https://bl-i.thgim.com/public/incoming/vwdrz2/article67325081.ece/alternates/LANDSCAPE_1200/IMG_Photo_8_final_2_1_3OAMIJU2.jpg',
#   'publishedAt': '2023-09-20T04:01:25Z',
#   'content': 'Citigroup Inc., BNP Paribas SA and Standard Chartered Plc are among the banks looking into providing financing for a new $15 billion program to protect Indian ocean habitats.\r\nThe banks, which also i… [+3559 chars]'},
#  {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#   'author': 'By DAVID KOENIG - AP Business Writer',
#   'title': 'United Auto Workers threaten to expand targeted strike if there is no substantive progress by Friday',
#   'description': 'The United Auto Workers union is preparing to expand its strike against Detroit’s Big Three unless it sees progress in contract negotiations. In a video statement late Monday, UAW President Shawn Fain said workers at more factories will join those…',
#   'url': 'https://apnews.com/article/strike-auto-workers-ford-gm-stellantis-f948704cce3d6dc9ca484142c5d0d98e',
#   'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/roanoke.com/content/tncms/assets/v3/editorial/f/00/f0058db0-1bef-5cfe-be38-19db2870d8f1/65097b721d4b8.image.jpg?crop=1763%2C926%2C0%2C124&resize=1200%2C630&order=crop%2Cresize',
#   'publishedAt': '2023-09-19T21:03:31Z',
#   'content': 'By DAVID KOENIG - AP Business Writer\r\nThe United Auto Workers union is stepping up pressure on Detroits Big Three by threatening to expand its strike unless it sees major progress in contract negotia… [+6113 chars]'},
#  {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#   'author': 'ap news',
#   'title': 'Lula pitches himself as fresh leader for Global South...',
#   'description': '“Brazil is back." That has been Luiz Inacio Lula da Silva’s refrain for the better part of the last year, with the newly elected president deploying the snappy slogan to cast Brazil and himself as leaders of the Global South. Last year, Lula thwarted the reel…',
#   'url': 'https://apnews.com/article/brazil-lula-un-general-assembly-global-south-fafdca8216d5fe43e4be72ab85135501',
#   'urlToImage': 'https://dims.apnews.com/dims4/default/107c642/2147483647/strip/true/crop/6000x3375+0+312/resize/1440x810!/quality/90/?url=https%3A%2F%2Fassets.apnews.com%2F31%2F81%2Fb9f0aab3182c13b7f83cd16a5bc8%2Fd5cec252f77448db98fcc3bf66cdf301',
#   'publishedAt': '2023-09-19T21:00:03Z',
#   'content': "Brazil's Lula pitches his nation — and himself — as fresh leader for Global SouthUNITED NATIONS (AP) — “Brazil is back.” That has been Luiz Inacio Lula da Silva’s refrain for the better part of the l… [+8005 chars]"},
#  {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#   'author': 'By AAMER MADHANI and SEUNG MIN KIM - Associated Press',
#   'title': "Biden exhorts world leaders at the UN to stand up to Russia, warns not to let Ukraine 'be carved up'",
#   'description': 'President Joe Biden has made his case before the U.N. General Assembly that the world must remain united in defending Ukraine against Russian aggression. In an address in New York on Tuesday, Biden warned that no nation can be secure…',
#   'url': 'https://apnews.com/article/biden-2023-unga-us-leadership-trump-04b25cd42d03caf194def2862f6eb8d5',
#   'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/roanoke.com/content/tncms/assets/v3/editorial/9/4a/94ac8df4-d663-5500-a114-483d25b93e40/65097b0285896.image.jpg?crop=1763%2C926%2C0%2C124&resize=1200%2C630&order=crop%2Cresize',
#   'publishedAt': '2023-09-19T19:15:05Z',
#   'content': 'By AAMER MADHANI and SEUNG MIN KIM - Associated Press\r\nUNITED NATIONS (AP) President Joe Biden made a robust case before the U.N. General Assembly on Tuesday that the world must remain united in defe… [+7265 chars]'},
#  {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#   'author': 'THOMAS ADAMSON',
#   'title': 'Journalist detained, home searched over reporting on French intelligence...',
#   'description': 'French investigative news outlet Disclose says one of its reporters has been arrested and her residence searched by the country’s domestic intelligence agency. Disclose said reporter Ariane Lavrilleux’s detention Tuesday was linked to her reporting on leaked …',
#   'url': 'https://apnews.com/article/france-egypt-journalist-arrested-disclose-intelligence-b8271893195a6ce22b1e1a8682caa728',
#   'urlToImage': 'https://dims.apnews.com/dims4/default/dcac1a4/2147483647/strip/true/crop/700x394+0+28/resize/1440x810!/quality/90/?url=https%3A%2F%2Fassets.apnews.com%2F90%2F29%2F4e3c1cc7446089a9101a7bdff4c8%2Fdefaultshareimage-copy.png',
#   'publishedAt': '2023-09-19T19:01:37Z',
#   'content': 'PARIS (AP) A French journalist was arrested and her residence searched Tuesday by the countrys domestic intelligence agency, her employer the investigative news outlet Disclose, said.\r\nDisclose said … [+1798 chars]'},
#  {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#   'author': 'AP',
#   'title': 'Officials find debris from F-35 fighter jet that crashed in South Carolina after pilot ejected',
#   'description': 'The crash site for a stealth fighter jet that went missing during the weekend after its pilot ejected has been located in rural South Carolina after the military asked the public for help finding an aircraft built to elude detection.…',
#   'url': 'https://apnews.com/article/missing-marine-f35-jet-south-carolina-mishap-b60ed0eb50791778b982be0c40a796a1',
#   'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/roanoke.com/content/tncms/assets/v3/editorial/5/25/52569716-23a3-50c4-95d2-eeb1e0c2e692/65097a79247d0.preview.jpg?crop=1920%2C1008%2C0%2C35&resize=1200%2C630&order=crop%2Cresize',
#   'publishedAt': '2023-09-19T17:22:31Z',
#   'content': 'NORTH CHARLESTON, S.C. (AP) The crash site for a stealth fighter jet that went missing during the weekend after its pilot ejected was located Monday in rural South Carolina after the military asked t… [+3194 chars]'}]

# %%
docs = [
    a["title"] + "\n\n" + (a["description"] or "") 
    for a in recent_articles
]

embeddings = OpenAIEmbeddings(chunk_size=1000).embed_documents(docs)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# f:\ai\langchain\Untitled-1.ipynb Cell 4 line 6
#       <a href='vscode-notebook-cell:/f%3A/ai/langchain/Untitled-1.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> docs = [
#       <a href='vscode-notebook-cell:/f%3A/ai/langchain/Untitled-1.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a>     a["title"] + "\n\n" + (a["description"] or "")
#       <a href='vscode-notebook-cell:/f%3A/ai/langchain/Untitled-1.ipynb#X22sZmlsZQ%3D%3D?line=2'>3</a>     for a in recent_articles
#       <a href='vscode-notebook-cell:/f%3A/ai/langchain/Untitled-1.ipynb#X22sZmlsZQ%3D%3D?line=3'>4</a> ]
# ----> <a href='vscode-notebook-cell:/f%3A/ai/langchain/Untitled-1.ipynb#X22sZmlsZQ%3D%3D?line=5'>6</a> embeddings = OpenAIEmbeddings(chunk_size=1000).embed_documents(docs)
#
# File f:\ai\langchain\venv\Lib\site-packages\langchain\embeddings\openai.py:490, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size)
#     478 """Call out to OpenAI's embedding endpoint for embedding search docs.
#     479
#     480 Args:
#    (...)
#     486     List of embeddings, one for each text.
#     487 """
#     488 # NOTE: to keep things simple, we assume the list may contain texts longer
#     489 #       than the maximum context and use length-safe embedding function.
# --> 490 return self._get_len_safe_embeddings(texts, engine=self.deployment)
#
# File f:\ai\langchain\venv\Lib\site-packages\langchain\embeddings\openai.py:374, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size)
#     371     _iter = range(0, len(tokens), _chunk_size)
#     373 for i in _iter:
# --> 374     response = embed_with_retry(
#     375         self,
#     376         input=tokens[i : i + _chunk_size],
#     377         **self._invocation_params,
#     378     )
#     379     batched_embeddings.extend(r["embedding"] for r in response["data"])
#     381 results: List[List[List[float]]] = [[] for _ in range(len(texts))]
#
# File f:\ai\langchain\venv\Lib\site-packages\langchain\embeddings\openai.py:107, in embed_with_retry(embeddings, **kwargs)
#     104     response = embeddings.client.create(**kwargs)
#     105     return _check_response(response, skip_empty=embeddings.skip_empty)
# --> 107 return _embed_with_retry(**kwargs)
#
# File f:\ai\langchain\venv\Lib\site-packages\tenacity\__init__.py:289, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     287 @functools.wraps(f)
#     288 def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289     return self(f, *args, **kw)
#
# File f:\ai\langchain\venv\Lib\site-packages\tenacity\__init__.py:379, in Retrying.__call__(self, fn, *args, **kwargs)
#     377 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     378 while True:
# --> 379     do = self.iter(retry_state=retry_state)
#     380     if isinstance(do, DoAttempt):
#     381         try:
#
# File f:\ai\langchain\venv\Lib\site-packages\tenacity\__init__.py:314, in BaseRetrying.iter(self, retry_state)
#     312 is_explicit_retry = fut.failed and isinstance(fut.exception(), TryAgain)
#     313 if not (is_explicit_retry or self.retry(retry_state)):
# --> 314     return fut.result()
#     316 if self.after is not None:
#     317     self.after(retry_state)
#
# File C:\Python311\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File C:\Python311\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File f:\ai\langchain\venv\Lib\site-packages\tenacity\__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     380 if isinstance(do, DoAttempt):
#     381     try:
# --> 382         result = fn(*args, **kwargs)
#     383     except BaseException:  # noqa: B902
#     384         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File f:\ai\langchain\venv\Lib\site-packages\langchain\embeddings\openai.py:104, in embed_with_retry.<locals>._embed_with_retry(**kwargs)
#     102 @retry_decorator
#     103 def _embed_with_retry(**kwargs: Any) -> Any:
# --> 104     response = embeddings.client.create(**kwargs)
#     105     return _check_response(response, skip_empty=embeddings.skip_empty)
#
# File f:\ai\langchain\venv\Lib\site-packages\openai\api_resources\embedding.py:33, in Embedding.create(cls, *args, **kwargs)
#      31 while True:
#      32     try:
# ---> 33         response = super().create(*args, **kwargs)
#      35         # If a user specifies base64, we'll just return the encoded string.
#      36         # This is only for the default case.
#      37         if not user_provided_encoding_format:
#
# File f:\ai\langchain\venv\Lib\site-packages\openai\api_resources\abstract\engine_api_resource.py:155, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     129 @classmethod
#     130 def create(
#     131     cls,
#    (...)
#     138     **params,
#     139 ):
#     140     (
#     141         deployment_id,
#     142         engine,
#    (...)
#     152         api_key, api_base, api_type, api_version, organization, **params
#     153     )
# --> 155     response, _, api_key = requestor.request(
#     156         "post",
#     157         url,
#     158         params=params,
#     159         headers=headers,
#     160         stream=stream,
#     161         request_id=request_id,
#     162         request_timeout=request_timeout,
#     163     )
#     165     if stream:
#     166         # must be an iterator
#     167         assert not isinstance(response, OpenAIResponse)
#
# File f:\ai\langchain\venv\Lib\site-packages\openai\api_requestor.py:289, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     278 def request(
#     279     self,
#     280     method,
#    (...)
#     287     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     288 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
# --> 289     result = self.request_raw(
#     290         method.lower(),
#     291         url,
#     292         params=params,
#     293         supplied_headers=headers,
#     294         files=files,
#     295         stream=stream,
#     296         request_id=request_id,
#     297         request_timeout=request_timeout,
#     298     )
#     299     resp, got_stream = self._interpret_response(result, stream)
#     300     return resp, got_stream, self.api_key
#
# File f:\ai\langchain\venv\Lib\site-packages\openai\api_requestor.py:606, in APIRequestor.request_raw(self, method, url, params, supplied_headers, files, stream, request_id, request_timeout)
#     604     _thread_context.session_create_time = time.time()
#     605 try:
# --> 606     result = _thread_context.session.request(
#     607         method,
#     608         abs_url,
#     609         headers=headers,
#     610         data=data,
#     611         files=files,
#     612         stream=stream,
#     613         timeout=request_timeout if request_timeout else TIMEOUT_SECS,
#     614         proxies=_thread_context.session.proxies,
#     615     )
#     616 except requests.exceptions.Timeout as e:
#     617     raise error.Timeout("Request timed out: {}".format(e)) from e
#
# File f:\ai\langchain\venv\Lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File f:\ai\langchain\venv\Lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File f:\ai\langchain\venv\Lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File f:\ai\langchain\venv\Lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File f:\ai\langchain\venv\Lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File f:\ai\langchain\venv\Lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File C:\Python311\Lib\http\client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File C:\Python311\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File C:\Python311\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File C:\Python311\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File C:\Python311\Lib\ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File C:\Python311\Lib\ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
hdb = hdbscan.HDBSCAN(min_samples=3, min_cluster_size=3).fit(embeddings)

df = pd.DataFrame({
    "title": [article["title"] for article in recent_articles],
    "description": [article["description"] for article in recent_articles],
    "cluster": hdb.labels_,
})
df = df.query("cluster != -1") # 删除不在群集中的文档

# %%
def get_prompt():
    system_template = "你是一位记者专家。你要帮我为新闻文章写一个引人注目的主题标题。"
    human_template = "使用以下文章，写一个能概括这些文章的主题标题。\n\nARTICLES:{articles}\n\nTOPIC TITLE:"
    
    return ChatPromptTemplate(
        messages=[
            SystemMessagePromptTemplate.from_template(system_template),
            HumanMessagePromptTemplate.from_template(human_template),
        ],
        input_variables=["articles"],
    )
    
for c in df.cluster.unique():
    chain = LLMChain(
        llm=ChatOpenAI(temperature=0, model_name="gpt-3.5-turbo-0613"), prompt=get_prompt(), verbose=False
    )
    articles_str = "\n".join(
        [
            f"{article['title']}\n{article['description']}\n"
            for article in df.query(f"cluster == {c}").to_dict(orient="records")
        ]
    )
    result = chain.run(
        {
            "articles": articles_str,
        }
    )
    df.loc[df.cluster == c, "topic_title"] = result

# %%
c = 1
with pd.option_context("display.max_colwidth", None):
    print(df.query(f"cluster == {c}").topic_title.values[0])
    display(df.query(f"cluster == {c}").drop(columns=["topic_title"]).head())
